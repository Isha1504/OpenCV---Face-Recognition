# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img=cv2.imread("sample_image.jpg")

# %%
print(img.shape)
# Out:
# (243, 364, 3)

# %%
plt.imshow(img)
plt.show()

# %%
# To make colors more visible and show the true colors of the image
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
print(img)
# Out:
# [[[ 21 130 233]
#   [ 21 130 233]
#   [ 21 130 231]
#   ...
#   [ 20 136 237]
#   [ 20 136 237]
#   [ 20 136 237]]
#
#  [[ 22 128 237]
#   [ 21 130 235]
#   [ 21 128 234]
#   ...
#   [ 20 136 237]
#   [ 20 136 237]
#   [ 20 136 237]]
#
#  [[ 22 126 241]
#   [ 21 126 241]
#   [ 22 126 241]
#   ...
#   [ 20 136 237]
#   [ 20 136 237]
#   [ 20 136 237]]
#
#  ...
#
#  [[ 62  57  53]
#   [ 68  64  61]
#   [ 78  76  77]
#   ...
#   [ 24  47  97]
#   [ 13  34  81]
#   [  2  23  68]]
#
#  [[ 46  45  43]
#   [ 42  44  43]
#   [ 46  51  54]
#   ...
#   [ 10  32  79]
#   [  8  29  74]
#   [  9  28  71]]
#
#  [[ 34  34  34]
#   [ 20  21  23]
#   [ 16  21  25]
#   ...
#   [  0  22  69]
#   [  4  23  66]
#   [  8  25  68]]]

# %%
#Resizing the image
img=cv2.resize(img,(100,100))
plt.imshow(img)
